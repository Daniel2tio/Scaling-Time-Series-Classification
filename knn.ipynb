# %% [markdown]
# ## Importing Requirements

# %%
import pandas as pd
from scipy.io import arff
from fastdtw import fastdtw
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %% [markdown]
# ## Reading the data

# %%
arff_file = arff.loadarff('ElectricDevices_TRAIN.arff')

# %%
df = pd.DataFrame(arff_file[0])
df.head()
# Out:
#        att1      att2      att3      att4      att5      att6      att7  \
# 0 -0.186109 -0.186109 -0.186109 -0.186109 -0.186109 -0.186109 -0.186109
# 1 -0.177005 -0.177005 -0.177005 -0.177005 -0.177005 -0.177005 -0.177005
# 2 -0.213535 -0.213535 -0.213535 -0.213535 -0.213535 -0.213535 -0.213535
# 3 -0.171472 -0.171472 -0.171472 -0.171472 -0.171472 -0.171472 -0.171472
# 4 -0.169266 -0.169266 -0.169266 -0.169266 -0.169266 -0.169266 -0.169266
#
#        att8      att9     att10  ...     att88     att89     att90     att91  \
# 0 -0.186109 -0.186109 -0.186109  ...  2.912740 -0.186109 -0.186109 -0.186109
# 1 -0.177005 -0.177005 -0.177005  ...  6.476670  1.645079 -0.177005 -0.177005
# 2 -0.213535 -0.213535 -0.213535  ... -0.213535 -0.213535 -0.213535 -0.213535
# 3 -0.171472 -0.171472 -0.171472  ...  0.180433  0.160882  7.355375  1.177495
# 4 -0.169266 -0.169266 -0.169266  ...  6.074392  0.170933  0.190945  0.190945
#
#       att92     att93     att94     att95     att96  target
# 0 -0.186109 -0.186109 -0.186109 -0.186109 -0.186109    b'1'
# 1 -0.177005 -0.177005 -0.177005 -0.177005 -0.177005    b'1'
# 2 -0.213535 -0.213535 -0.213535 -0.213535 -0.213535    b'1'
# 3 -0.171472 -0.171472 -0.171472 -0.171472 -0.171472    b'1'
# 4  7.395165  0.851332 -0.169266 -0.169266 -0.169266    b'1'
#
# [5 rows x 97 columns]

# %%
df.tail()
# Out:
#           att1      att2      att3      att4      att5      att6      att7  \
# 8921 -0.611983 -0.611983 -0.611983 -0.611983 -0.611983 -0.611983 -0.611983
# 8922 -0.498369 -0.498369 -0.498369 -0.498369 -0.498369 -0.498369 -0.498369
# 8923 -0.399394 -0.399394 -0.399394 -0.399394 -0.399394 -0.399394 -0.399394
# 8924 -0.595599 -0.595599 -0.595599 -0.595599 -0.595599 -0.595599 -0.595599
# 8925 -0.545183 -0.545183 -0.545183 -0.545183 -0.545183 -0.545183 -0.545183
#
#           att8      att9     att10  ...     att88     att89     att90  \
# 8921 -0.611983 -0.611983 -0.611983  ...  1.628497  1.711478  1.711478
# 8922 -0.498369 -0.498369 -0.498369  ...  2.315952  2.315952  2.218906
# 8923 -0.399394 -0.399394 -0.399394  ...  2.646940  2.646940  2.436848
# 8924 -0.595599 -0.595599 -0.595599  ...  1.783125  1.783125  1.871226
# 8925 -0.545183 -0.545183 -0.545183  ...  2.003086  2.199107  2.101097
#
#          att91     att92     att93     att94     att95     att96  target
# 8921  1.711478  1.628497 -0.611983 -0.611983 -0.611983 -0.611983    b'5'
# 8922  2.218906  1.733678 -0.498369 -0.498369 -0.498369 -0.498369    b'5'
# 8923  2.646940  2.541894  0.440974 -0.399394 -0.399394 -0.399394    b'5'
# 8924  1.783125  1.783125  1.783125  1.871226  1.871226  1.783125    b'5'
# 8925  2.199107  2.101097  0.042880 -0.545183 -0.545183 -0.545183    b'5'
#
# [5 rows x 97 columns]

# %%
df['target'].tail(50)
# Out:
# 8876    b'5'
# 8877    b'5'
# 8878    b'5'
# 8879    b'5'
# 8880    b'5'
# 8881    b'5'
# 8882    b'5'
# 8883    b'5'
# 8884    b'5'
# 8885    b'5'
# 8886    b'5'
# 8887    b'5'
# 8888    b'5'
# 8889    b'5'
# 8890    b'5'
# 8891    b'5'
# 8892    b'5'
# 8893    b'5'
# 8894    b'5'
# 8895    b'5'
# 8896    b'5'
# 8897    b'5'
# 8898    b'5'
# 8899    b'5'
# 8900    b'5'
# 8901    b'5'
# 8902    b'5'
# 8903    b'5'
# 8904    b'5'
# 8905    b'5'
# 8906    b'5'
# 8907    b'5'
# 8908    b'5'
# 8909    b'5'
# 8910    b'5'
# 8911    b'5'
# 8912    b'5'
# 8913    b'5'
# 8914    b'5'
# 8915    b'5'
# 8916    b'5'
# 8917    b'5'
# 8918    b'5'
# 8919    b'5'
# 8920    b'5'
# 8921    b'5'
# 8922    b'5'
# 8923    b'5'
# 8924    b'5'
# 8925    b'5'
# Name: target, dtype: object

# %% [markdown]
# ## Pre-processing

# %%
df.fillna(method='ffill', inplace=True)

# %%
# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(df.drop('target', axis=1), df['target'], test_size=0.2)

# %%
# Check the type and shape of X_train and y_train
print("X_train shape:", X_train.shape)
print("y_train type:", type(y_train))
print("Unique labels in y_train:", y_train.unique())
# Out:
# X_train shape: (7140, 96)
# y_train type: <class 'pandas.core.series.Series'>
# Unique labels in y_train: [b'4' b'1' b'2' b'3' b'5' b'7' b'6']

# %%
from sklearn.preprocessing import LabelEncoder

# Convert byte-string labels to strings
y_train_str = y_train.str.decode('utf-8')

# Encode labels into numerical format
label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train_str)


def dtw_distance(ts1, ts2):
    distance, _ = fastdtw(ts1, ts2)
    return distance

# Define kNN with DTW as distance metric
knn_dtw = KNeighborsClassifier(n_neighbors=5, metric=dtw_distance)

# Fit the kNN classifier
knn_dtw.fit(X_train, y_train_encoded)
# Out:
# KNeighborsClassifier(metric=<function dtw_distance at 0x00000232BA4DFEB0>)

# %%
from sklearn.metrics import accuracy_score

batch_size = 1000
y_pred = []

for i in range(0, len(X_test), batch_size):
    X_batch = X_test.iloc[i:i+batch_size]
    batch_predictions = knn_dtw.predict(X_batch)
    y_pred.extend(batch_predictions)

# Convert test labels to numerical format if needed
y_test_encoded = label_encoder.transform(y_test.str.decode('utf-8'))

# Calculate accuracy
accuracy = accuracy_score(y_test_encoded, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[38], line 8
#       6 for i in range(0, len(X_test), batch_size):
#       7     X_batch = X_test.iloc[i:i+batch_size]
# ----> 8     batch_predictions = knn_dtw.predict(X_batch)
#       9     y_pred.extend(batch_predictions)
#      11 # Convert test labels to numerical format if needed
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\neighbors\_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\neighbors\_base.py:861, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     858     else:
#     859         kwds = self.effective_metric_params_
# --> 861     chunked_results = list(
#     862         pairwise_distances_chunked(
#     863             X,
#     864             self._fit_X,
#     865             reduce_func=reduce_func,
#     866             metric=self.effective_metric_,
#     867             n_jobs=n_jobs,
#     868             **kwds,
#     869         )
#     870     )
#     872 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     873     if issparse(X):
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1623, in _pairwise_callable(X, Y, metric, force_all_finite, **kwds)
#    1621     iterator = itertools.product(range(X.shape[0]), range(Y.shape[0]))
#    1622     for i, j in iterator:
# -> 1623         out[i, j] = metric(X[i], Y[j], **kwds)
#    1625 return out
#
# Cell In[37], line 12, in dtw_distance(ts1, ts2)
#      11 def dtw_distance(ts1, ts2):
# ---> 12     distance, _ = fastdtw(ts1, ts2)
#      13     return distance
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:53, in fastdtw(x, y, radius, dist)
#      16 ''' return the approximate distance between 2 time series with O(N)
#      17     time and memory complexity
#      18
#    (...)
#      50     (2.0, [(0, 0), (1, 0), (2, 1), (3, 2), (4, 2)])
#      51 '''
#      52 x, y, dist = __prep_inputs(x, y, dist)
# ---> 53 return __fastdtw(x, y, radius, dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:75, in __fastdtw(x, y, radius, dist)
#      72 distance, path = \
#      73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
# ---> 75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:142, in __dtw(x, y, window, dist)
#     140 for i, j in window:
#     141     dt = dist(x[i-1], y[j-1])
# --> 142     D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
#     143                   (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#     144 path = []
#     145 i, j = len_x, len_y
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:143, in __dtw.<locals>.<lambda>(a)
#     140 for i, j in window:
#     141     dt = dist(x[i-1], y[j-1])
#     142     D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
# --> 143                   (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#     144 path = []
#     145 i, j = len_x, len_y
#
# KeyboardInterrupt:

# %%
batch_size = 1000
y_pred = []

for i in range(0, len(X_test), batch_size):
    X_batch = X_test.iloc[i:i+batch_size]
    y_batch_pred = knn_dtw.predict(X_batch)
    y_pred.extend(y_batch_pred)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

# %% [markdown]
# ## Training Model & Parameter Search

# %%
# Predict and evaluate
y_pred = knn_dtw.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 2
#       1 # Predict and evaluate
# ----> 2 y_pred = knn_dtw.predict(X_test)
#       3 accuracy = accuracy_score(y_test, y_pred)
#       4 print("Accuracy:", accuracy)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\neighbors\_classification.py:234, in KNeighborsClassifier.predict(self, X)
#     218 """Predict the class labels for the provided data.
#     219
#     220 Parameters
#    (...)
#     229     Class labels for each data sample.
#     230 """
#     231 if self.weights == "uniform":
#     232     # In that case, we do not need the distances to perform
#     233     # the weighting so we do not compute them.
# --> 234     neigh_ind = self.kneighbors(X, return_distance=False)
#     235     neigh_dist = None
#     236 else:
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\neighbors\_base.py:861, in KNeighborsMixin.kneighbors(self, X, n_neighbors, return_distance)
#     858     else:
#     859         kwds = self.effective_metric_params_
# --> 861     chunked_results = list(
#     862         pairwise_distances_chunked(
#     863             X,
#     864             self._fit_X,
#     865             reduce_func=reduce_func,
#     866             metric=self.effective_metric_,
#     867             n_jobs=n_jobs,
#     868             **kwds,
#     869         )
#     870     )
#     872 elif self._fit_method in ["ball_tree", "kd_tree"]:
#     873     if issparse(X):
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1867, in pairwise_distances_chunked(X, Y, reduce_func, metric, n_jobs, working_memory, **kwds)
#    1865 else:
#    1866     X_chunk = X[sl]
# -> 1867 D_chunk = pairwise_distances(X_chunk, Y, metric=metric, n_jobs=n_jobs, **kwds)
#    1868 if (X is Y or Y is None) and PAIRWISE_DISTANCE_FUNCTIONS.get(
#    1869     metric, None
#    1870 ) is euclidean_distances:
#    1871     # zeroing diagonal, taking care of aliases of "euclidean",
#    1872     # i.e. "l2"
#    1873     D_chunk.flat[sl.start :: _num_samples(X) + 1] = 0
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:2039, in pairwise_distances(X, Y, metric, n_jobs, force_all_finite, **kwds)
#    2036         return distance.squareform(distance.pdist(X, metric=metric, **kwds))
#    2037     func = partial(distance.cdist, metric=metric, **kwds)
# -> 2039 return _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1579, in _parallel_pairwise(X, Y, func, n_jobs, **kwds)
#    1576 X, Y, dtype = _return_float_dtype(X, Y)
#    1578 if effective_n_jobs(n_jobs) == 1:
# -> 1579     return func(X, Y, **kwds)
#    1581 # enforce a threading backend to prevent data communication overhead
#    1582 fd = delayed(_dist_wrapper)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\sklearn\metrics\pairwise.py:1623, in _pairwise_callable(X, Y, metric, force_all_finite, **kwds)
#    1621     iterator = itertools.product(range(X.shape[0]), range(Y.shape[0]))
#    1622     for i, j in iterator:
# -> 1623         out[i, j] = metric(X[i], Y[j], **kwds)
#    1625 return out
#
# Cell In[15], line 2, in dtw_distance(ts1, ts2)
#       1 def dtw_distance(ts1, ts2):
# ----> 2     distance, _ = fastdtw(ts1, ts2)
#       3     return distance
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:53, in fastdtw(x, y, radius, dist)
#      16 ''' return the approximate distance between 2 time series with O(N)
#      17     time and memory complexity
#      18
#    (...)
#      50     (2.0, [(0, 0), (1, 0), (2, 1), (3, 2), (4, 2)])
#      51 '''
#      52 x, y, dist = __prep_inputs(x, y, dist)
# ---> 53 return __fastdtw(x, y, radius, dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:73, in __fastdtw(x, y, radius, dist)
#      70 x_shrinked = __reduce_by_half(x)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
# ---> 73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:73, in __fastdtw(x, y, radius, dist)
#      70 x_shrinked = __reduce_by_half(x)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
# ---> 73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:73, in __fastdtw(x, y, radius, dist)
#      70 x_shrinked = __reduce_by_half(x)
#      71 y_shrinked = __reduce_by_half(y)
#      72 distance, path = \
# ---> 73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
#      75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:75, in __fastdtw(x, y, radius, dist)
#      72 distance, path = \
#      73     __fastdtw(x_shrinked, y_shrinked, radius=radius, dist=dist)
#      74 window = __expand_window(path, len(x), len(y), radius)
# ---> 75 return __dtw(x, y, window, dist=dist)
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:142, in __dtw(x, y, window, dist)
#     140 for i, j in window:
#     141     dt = dist(x[i-1], y[j-1])
# --> 142     D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
#     143                   (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#     144 path = []
#     145 i, j = len_x, len_y
#
# File c:\Users\danie\anaconda3\envs\COMP4030\lib\site-packages\fastdtw\fastdtw.py:143, in __dtw.<locals>.<lambda>(a)
#     140 for i, j in window:
#     141     dt = dist(x[i-1], y[j-1])
#     142     D[i, j] = min((D[i-1, j][0]+dt, i-1, j), (D[i, j-1][0]+dt, i, j-1),
# --> 143                   (D[i-1, j-1][0]+dt, i-1, j-1), key=lambda a: a[0])
#     144 path = []
#     145 i, j = len_x, len_y
#
# KeyboardInterrupt:

# %%
from sklearn.model_selection import GridSearchCV

knn_dtw = KNeighborsClassifier(metric=dtw_distance)

# Define parameter grid for grid search
param_grid = {'n_neighbors': [3, 5, 7, 10]}
grid_search = GridSearchCV(knn_dtw, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train_encoded)


print("Best Parameters:", grid_search.best_params_)
print("Best CV Score (Accuracy):", grid_search.best_score_)

# %% [markdown]
# ## Visualisations

# %%
import matplotlib.pyplot as plt

# Plot some sample time-series
num_samples = 5
sample_indices = np.random.choice(len(X_train), num_samples, replace=False)

plt.figure(figsize=(12, 6))
for i, idx in enumerate(sample_indices):
    plt.subplot(num_samples, 1, i + 1)
    plt.plot(X_train.iloc[idx])
    plt.title(f"Time-Series Sample {idx}")
    plt.xlabel("Time")
    plt.ylabel("Value")
plt.tight_layout()
plt.show()

# %%
import seaborn as sns

# Count plot of class distribution
plt.figure(figsize=(8, 6))
sns.countplot(x=y_train_str)
plt.title("Class Distribution")
plt.xlabel("Class")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
# Compute descriptive statistics of time-series features
feature_stats = X_train.describe()

# Visualize statistics (e.g., mean, min, max)
plt.figure(figsize=(10, 6))
sns.boxplot(data=feature_stats.T)
plt.title("Feature Statistics")
plt.xlabel("Statistic")
plt.ylabel("Value")
plt.xticks(rotation=45)
plt.show()

# %%
# Compute correlation matrix
corr_matrix = X_train.corr()

# Visualize correlation matrix
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
plt.title("Correlation Matrix of Time-Series Features")
plt.show()

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# Perform seasonal decomposition
decomposition = seasonal_decompose(X_train.iloc[0], model='additive', period=24)  # Assuming hourly data

# Plot decomposition components
plt.figure(figsize=(12, 8))
decomposition.plot()
plt.suptitle("Seasonal Decomposition of a Time-Series")
plt.show()

# %% [markdown]
# ## Improving Results

# %%
from tsfresh import extract_features

# Extract features from time-series data
X_train_features = extract_features(X_train, column_id='time_series_id', default_fc_parameters=None)

# %%
from sklearn.decomposition import PCA

# Applying PCA for dimensionality reduction
pca = PCA(n_components=10)  
X_train_pca = pca.fit_transform(X_train)

# %%
import time

#Checking the time based on performance improvements

for
